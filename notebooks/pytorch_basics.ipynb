# %%
import torch 

x = torch.tensor([[1.0,2.0], [3.0,4.0]])
print(x.shape)
print(x.dtype)
print(x+1)
print(x @ x)

print (x.mean())
print(x.sum(dim=0))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2
#       3 x = torch.tensor([[1.0,2.0], [3.0,4.0]])
#       4 print(x.shape)
#
# File ~\doc-assistant-\venv\Lib\site-packages\torch\__init__.py:309
#     305                     raise err
#     307         kernel32.SetErrorMode(prev_error_mode)
# --> 309     _load_dll_libraries()
#     310     del _load_dll_libraries
#     313 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     314     # Libraries can either be in
#     315     # path/nvidia/lib_folder/lib or
#     316     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     317     # path/lib_folder/lib
#
# File ~\doc-assistant-\venv\Lib\site-packages\torch\__init__.py:292, in _load_dll_libraries()
#     288     err = ctypes.WinError(last_error)
#     289     err.strerror += (
# ...

# %%
w = torch.tensor(3.0,requires_grad = True)

y = w**2

y = backward()
print(y)
print(w.grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 w = torch.tensor(3.0,requires_grad = True)
#       2
#       3 y = w**2
#       4
#
# NameError: name 'torch' is not defined
